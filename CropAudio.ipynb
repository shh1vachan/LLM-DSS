# %%
import json
import os

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (21.2.4)Note: you may need to restart the kernel to use updated packages.
#
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-25.1.1

# %% [markdown]
# ## Pyannote VAD

# %%
from pyannote.audio import Pipeline
from pydub import AudioSegment

pipeline = Pipeline.from_pretrained("pyannote/voice-activity-detection", use_auth_token="YOUR_HF_TOKEN")

manifest_path = "manifest.jsonl"
output_dir = "segmented_audio"
os.makedirs(output_dir, exist_ok=True)

new_manifest = []

with open(manifest_path, "r", encoding="utf-8") as f:
    lines = f.readlines()

total_files = len(lines)
print(f"Total files to process: {total_files}")

for idx, line in enumerate(lines):
    item = json.loads(line)
    audio_path = item["audio_filepath"].replace("\\", "/")
    text = item["text"]

    print(f"\n[{idx+1}/{total_files}] Processing: {audio_path}")

    try:
        audio = AudioSegment.from_file(audio_path)
    except Exception as e:
        print(f"  [ERROR] Could not load audio: {e}")
        continue

    try:
        vad_result = pipeline(audio_path)
        segments = vad_result.get_timeline().support()
        num_segments = len(segments)
        print(f"  Detected {num_segments} speech segments")

        if num_segments == 0:
            print("  [WARN] No speech segments found, saving entire audio as one segment")
            segment_filename = f"{os.path.splitext(os.path.basename(audio_path))[0]}_segment0.wav"
            segment_path = os.path.join(output_dir, segment_filename)
            audio.export(segment_path, format="wav")
            new_manifest.append({
                "audio_filepath": segment_path,
                "text": text
            })
            continue

        words = text.split()
        words_per_segment = max(1, len(words) // num_segments)
        start_word = 0

        for i, segment in enumerate(segments):
            start_ms = int(segment.start * 1000)
            end_ms = int(segment.end * 1000)
            audio_chunk = audio[start_ms:end_ms]

            segment_filename = f"{os.path.splitext(os.path.basename(audio_path))[0]}_segment{i}.wav"
            segment_path = os.path.join(output_dir, segment_filename)
            audio_chunk.export(segment_path, format="wav")

            end_word = start_word + words_per_segment
            text_chunk = " ".join(words[start_word:end_word])
            start_word = end_word

            new_manifest.append({
                "audio_filepath": segment_path,
                "text": text_chunk
            })
    except Exception as e:
        print(f"  [ERROR] VAD processing failed: {e}")

with open("manifest_segmented.jsonl", "w", encoding="utf-8") as f_out:
    for entry in new_manifest:
        f_out.write(json.dumps(entry, ensure_ascii=False) + "\n")

print(f"\nCreated segmented dataset with {len(new_manifest)} samples.")

# %% [markdown]
# ## Silero VAD

# %%
# %pip install torchaudio pydub
# %pip install git+https://github.com/snakers4/silero-vad.git
# Out:
# Requirement already satisfied: torchaudio in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (2.7.1+cu118)
# Requirement already satisfied: pydub in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (0.25.1)
# Requirement already satisfied: torch==2.7.1+cu118 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torchaudio) (2.7.1+cu118)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from torch==2.7.1+cu118->torchaudio) (4.14.0)
# Requirement already satisfied: networkx in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch==2.7.1+cu118->torchaudio) (3.4.2)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch==2.7.1+cu118->torchaudio) (3.18.0)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch==2.7.1+cu118->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch==2.7.1+cu118->torchaudio) (2024.12.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch==2.7.1+cu118->torchaudio) (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch==2.7.1+cu118->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch==2.7.1+cu118->torchaudio) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Admin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Collecting git+https://github.com/snakers4/silero-vad.git
#   Cloning https://github.com/snakers4/silero-vad.git to c:\users\admin\appdata\local\temp\pip-req-build-l98z9uhc
#   Resolved https://github.com/snakers4/silero-vad.git to commit 94811cbe1207ec24bc0f5370b895364b8934936f
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: onnxruntime>=1.16.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from silero-vad==5.1.2) (1.22.0)
# Requirement already satisfied: torchaudio>=0.12.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from silero-vad==5.1.2) (2.7.1+cu118)
# Requirement already satisfied: torch>=1.12.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from silero-vad==5.1.2) (2.7.1+cu118)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (1.24.4)
# Requirement already satisfied: flatbuffers in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (25.2.10)
# Requirement already satisfied: packaging in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (25.0)
# Requirement already satisfied: protobuf in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (4.24.4)
# Requirement already satisfied: sympy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (1.13.3)
# Requirement already satisfied: coloredlogs in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.16.1->silero-vad==5.1.2) (15.0.1)
# Requirement already satisfied: fsspec in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad==5.1.2) (2024.12.0)
# Requirement already satisfied: networkx in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad==5.1.2) (3.4.2)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad==5.1.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from torch>=1.12.0->silero-vad==5.1.2) (4.14.0)
# Requirement already satisfied: jinja2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.12.0->silero-vad==5.1.2) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.16.1->silero-vad==5.1.2) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.16.1->silero-vad==5.1.2) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.16.1->silero-vad==5.1.2) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.12.0->silero-vad==5.1.2) (3.0.2)
# Building wheels for collected packages: silero-vad
#   Building wheel for silero-vad (PEP 517): started
#   Building wheel for silero-vad (PEP 517): finished with status 'done'
#   Created wheel for silero-vad: filename=silero_vad-5.1.2-py3-none-any.whl size=6114613 sha256=a2eb9545cfde8244645482275646dcd175e43476773d5c09323e4399a6868cb2
#   Stored in directory: C:\Users\Admin\AppData\Local\Temp\pip-ephem-wheel-cache-76i5tw_d\wheels\82\7f\66\ea5a08dbeba0681afb1d287a7f1b0b0bd7a56accf01920194a
# Successfully built silero-vad
# Installing collected packages: silero-vad
# Successfully installed silero-vad-5.1.2
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/snakers4/silero-vad.git 'C:\Users\Admin\AppData\Local\Temp\pip-req-build-l98z9uhc'
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Admin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import os
import json
import torch
from pydub import AudioSegment
from transformers import WhisperProcessor

# Load Silero VAD
model, utils = torch.hub.load('snakers4/silero-vad', model='silero_vad', force_reload=False)
(get_speech_timestamps, _, read_audio, _, _) = utils

# Load Whisper tokenizer
processor = WhisperProcessor.from_pretrained("openai/whisper-large-v3", language="russian", task="transcribe")
tokenizer = processor.tokenizer

# Параметры
manifest_path = "manifest.jsonl"
output_dir = "segmented_audio_silero_v2"
output_manifest = "manifest_silero_v2.jsonl"
max_audio_len_sec = 30
max_tokens = 448
chunk_overlap_ms = 1000  # для "мягкой" резки длинных кусков

os.makedirs(output_dir, exist_ok=True)
new_manifest = []

# Загрузка манифеста
with open(manifest_path, "r", encoding="utf-8") as f:
    lines = f.readlines()

print(f"Total files to process: {len(lines)}")

for idx, line in enumerate(lines):
    item = json.loads(line)
    audio_path = item["audio_filepath"].replace("\\", "/")
    full_text = item["text"].strip()
    words = full_text.split()

    print(f"\n[{idx+1}/{len(lines)}] Processing: {audio_path}")

    try:
        waveform = read_audio(audio_path, sampling_rate=16000)
        vad_segments = get_speech_timestamps(waveform, model, sampling_rate=16000)
        audio = AudioSegment.from_file(audio_path)
    except Exception as e:
        print(f"  [ERROR] Audio load failed: {e}")
        continue

    if len(vad_segments) == 0:
        print("  [WARN] No speech found, saving whole audio")
        segment_path = os.path.join(output_dir, f"{os.path.basename(audio_path)}_segment0.wav")
        audio.export(segment_path, format="wav")
        new_manifest.append({"audio_filepath": segment_path, "text": full_text})
        continue

    total_audio_duration_ms = sum([s["end"] - s["start"] for s in vad_segments])
    word_cursor = 0

    for i, seg in enumerate(vad_segments):
        start_ms = seg["start"] // 16
        end_ms = seg["end"] // 16
        chunk_duration = (end_ms - start_ms) / 1000.0
        chunk = audio[start_ms:end_ms]

        if chunk_duration > max_audio_len_sec:
            print(f"  [LONG] Segment {i} is {chunk_duration:.1f}s → splitting")
            step = max_audio_len_sec * 1000
            for j in range(start_ms, end_ms, int(step - chunk_overlap_ms)):
                part_start = j
                part_end = min(end_ms, j + int(step))
                subchunk = audio[part_start:part_end]
                sub_duration = (part_end - part_start) / 1000.0
  
                segment_name = f"{os.path.splitext(os.path.basename(audio_path))[0]}_segment{i}_{j}.wav"
                segment_path = os.path.join(output_dir, segment_name)
                subchunk.export(segment_path, format="wav")

                # Назначаем пропорционально текст
                words_per_chunk = max(1, int(sub_duration / total_audio_duration_ms * len(words)))
                text_chunk = " ".join(words[word_cursor:word_cursor + words_per_chunk])
                word_cursor += words_per_chunk

                # Токенизация и проверка длины
                if len(tokenizer(text_chunk)["input_ids"]) <= max_tokens:
                    new_manifest.append({"audio_filepath": segment_path, "text": text_chunk})
        else:
            segment_name = f"{os.path.splitext(os.path.basename(audio_path))[0]}_segment{i}.wav"
            segment_path = os.path.join(output_dir, segment_name)
            chunk.export(segment_path, format="wav")

            words_per_chunk = max(1, int((seg["end"] - seg["start"]) / total_audio_duration_ms * len(words)))
            text_chunk = " ".join(words[word_cursor:word_cursor + words_per_chunk])
            word_cursor += words_per_chunk

            if len(tokenizer(text_chunk)["input_ids"]) <= max_tokens:
                new_manifest.append({"audio_filepath": segment_path, "text": text_chunk})

# Сохраняем манифест
with open(output_manifest, "w", encoding="utf-8") as f_out:
    for item in new_manifest:
        f_out.write(json.dumps(item, ensure_ascii=False) + "\n")

print(f"\n✅ Done: {len(new_manifest)} segments saved to {output_manifest}")
# Out:
# Using cache found in C:\Users\Admin/.cache\torch\hub\snakers4_silero-vad_master
# Total files to process: 5190
#
# [1/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (1).wav
#
# [2/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (10).wav
#
# [3/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (100).wav
#
# [4/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (101).wav
#
# [5/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (102).wav
#
# [6/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (103).wav
#
# [7/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (104).wav
#
# [8/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (105).wav
#
# [9/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (106).wav
#
# [10/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (107).wav
#
# [11/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (108).wav
#
# [12/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (109).wav
#
# [13/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (11).wav
#
# [14/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (110).wav
#
# [15/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (111).wav
#
# [16/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (112).wav
#
# [17/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (113).wav
#
# [18/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (114).wav
#
# [19/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (115).wav
#
# [20/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (116).wav
#
# [21/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (117).wav
#
# [22/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (118).wav
#
# [23/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (119).wav
#
# [24/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (12).wav
#
# [25/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (120).wav
#
# [26/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (121).wav
#   [WARN] No speech found, saving whole audio
#
# [27/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (122).wav
#
# [28/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (123).wav
#
# [29/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (124).wav
#
# [30/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (125).wav
#
# [31/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (126).wav
#
# [32/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (127).wav
#
# [33/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (128).wav
#
# [34/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (129).wav
#
# [35/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (13).wav
#
# [36/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (130).wav
#
# [37/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (131).wav
#
# [38/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (132).wav
#
# [39/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (133).wav
#
# [40/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (134).wav
#
# [41/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (135).wav
#
# [42/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (136).wav
#
# [43/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (137).wav
#
# [44/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (138).wav
#
# [45/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (139).wav
#
# [46/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (14).wav
#
# [47/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (140).wav
#
# [48/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (141).wav
#
# [49/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (142).wav
#
# [50/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (143).wav
#
# [51/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (144).wav
#
# [52/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (145).wav
#
# [53/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (146).wav
#
# [54/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (147).wav
#
# [55/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (148).wav
#
# [56/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (149).wav
#
# [57/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (15).wav
#
# [58/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (150).wav
#
# [59/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (151).wav
#
# [60/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (152).wav
#
# [61/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (153).wav
#
# [62/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (154).wav
#
# [63/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (155).wav
#
# [64/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (156).wav
#
# [65/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (157).wav
#
# [66/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (158).wav
#
# [67/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (159).wav
#
# [68/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (16).wav
#
# [69/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (160).wav
#
# [70/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (161).wav
#
# [71/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (162).wav
#
# [72/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (163).wav
#
# [73/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (164).wav
#
# [74/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (165).wav
#
# [75/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (166).wav
#
# [76/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (167).wav
#
# [77/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (168).wav
#
# [78/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (169).wav
#
# [79/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (17).wav
#
# [80/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (170).wav
#
# [81/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (171).wav
#
# [82/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (172).wav
#
# [83/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (173).wav
#
# [84/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (174).wav
#
# [85/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (175).wav
#
# [86/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (176).wav
#
# [87/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (177).wav
#
# [88/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (178).wav
#
# [89/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (179).wav
#
# [90/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (18).wav
#
# [91/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (180).wav
#
# [92/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (181).wav
#
# [93/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (182).wav
#
# [94/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (183).wav
#
# [95/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (184).wav
#
# [96/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (185).wav
#
# [97/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (186).wav
#
# [98/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (187).wav
#
# [99/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (188).wav
#
# [100/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (189).wav
#
# [101/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (19).wav
#
# [102/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (190).wav
#
# [103/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (191).wav
#
# [104/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (192).wav
#
# [105/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (193).wav
#
# [106/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (194).wav
#
# [107/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (195).wav
#
# [108/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (196).wav
#
# [109/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (197).wav
#
# [110/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (198).wav
#
# [111/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (199).wav
#
# [112/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (2).wav
#
# [113/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (20).wav
#
# [114/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (200).wav
#
# [115/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (201).wav
#
# [116/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (202).wav
#
# [117/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (203).wav
#
# [118/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (204).wav
#
# [119/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (205).wav
#
# [120/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (206).wav
#
# [121/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (207).wav
#
# [122/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (208).wav
#
# [123/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (209).wav
#
# [124/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (21).wav
#
# [125/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (210).wav
#
# [126/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (211).wav
#
# [127/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (212).wav
#
# [128/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (213).wav
#
# [129/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (214).wav
#
# [130/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (215).wav
#
# [131/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (216).wav
#
# [132/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (217).wav
#
# [133/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (218).wav
#
# [134/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (219).wav
#
# [135/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (22).wav
#
# [136/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (220).wav
#
# [137/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (221).wav
#
# [138/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (222).wav
#
# [139/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (223).wav
#
# [140/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (224).wav
#
# [141/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (225).wav
#
# [142/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (226).wav
#
# [143/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (227).wav
#
# [144/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (228).wav
#
# [145/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (229).wav
#
# [146/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (23).wav
#
# [147/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (230).wav
#
# [148/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (231).wav
#
# [149/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (232).wav
#
# [150/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (233).wav
#
# [151/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (234).wav
#
# [152/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (235).wav
#
# [153/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (236).wav
#
# [154/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (237).wav
#
# [155/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (238).wav
#
# [156/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (24).wav
#
# [157/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (240).wav
#
# [158/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (241).wav
#
# [159/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (242).wav
#
# [160/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (243).wav
#
# [161/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (244).wav
#
# [162/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (245).wav
#
# [163/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (246).wav
#
# [164/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (247).wav
#
# [165/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (248).wav
#
# [166/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (249).wav
#
# [167/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (25).wav
#
# [168/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (250).wav
#
# [169/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (251).wav
#
# [170/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (252).wav
#
# [171/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (253).wav
#
# [172/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (254).wav
#
# [173/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (255).wav
#
# [174/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (256).wav
#
# [175/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (257).wav
#
# [176/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (258).wav
#
# [177/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (259).wav
#
# [178/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (26).wav
#
# [179/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (260).wav
#
# [180/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (261).wav
#
# [181/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (262).wav
#
# [182/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (263).wav
#
# [183/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (264).wav
#
# [184/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (265).wav
#
# [185/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (266).wav
#
# [186/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (267).wav
#
# [187/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (268).wav
#
# [188/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (269).wav
#
# [189/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (27).wav
#
# [190/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (270).wav
#
# [191/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (271).wav
#
# [192/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (272).wav
#
# [193/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (273).wav
#
# [194/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (274).wav
#
# [195/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (275).wav
#
# [196/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (276).wav
#
# [197/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (277).wav
#
# [198/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (278).wav
#
# [199/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (279).wav
#
# [200/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (28).wav
#
# [201/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (281).wav
#
# [202/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (282).wav
#
# [203/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (283).wav
#
# [204/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (284).wav
#
# [205/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (285).wav
#
# [206/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (286).wav
#
# [207/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (287).wav
#
# [208/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (288).wav
#
# [209/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (289).wav
#
# [210/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (29).wav
#
# [211/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (290).wav
#
# [212/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (291).wav
#
# [213/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (292).wav
#
# [214/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (293).wav
#
# [215/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (294).wav
#
# [216/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (295).wav
#
# [217/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (296).wav
#
# [218/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (297).wav
#
# [219/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (298).wav
#
# [220/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (299).wav
#
# [221/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (3).wav
#
# [222/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (30).wav
#
# [223/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (300).wav
#
# [224/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (301).wav
#
# [225/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (302).wav
#
# [226/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (303).wav
#
# [227/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (304).wav
#
# [228/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (305).wav
#
# [229/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (306).wav
#
# [230/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (307).wav
#
# [231/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (308).wav
#
# [232/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (309).wav
#
# [233/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (31).wav
#
# [234/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (310).wav
#
# [235/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (311).wav
#
# [236/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (312).wav
#
# [237/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (313).wav
#
# [238/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (314).wav
#
# [239/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (315).wav
#
# [240/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (316).wav
#
# [241/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (317).wav
#
# [242/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (318).wav
#
# [243/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (319).wav
#
# [244/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (32).wav
#
# [245/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (320).wav
#
# [246/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (321).wav
#
# [247/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (322).wav
#
# [248/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (323).wav
#
# [249/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (324).wav
#
# [250/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (325).wav
#
# [251/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (326).wav
#
# [252/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (327).wav
#
# [253/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (328).wav
#
# [254/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (329).wav
#
# [255/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (33).wav
#
# [256/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (330).wav
#
# [257/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (331).wav
#
# [258/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (332).wav
#
# [259/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (333).wav
#
# [260/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (334).wav
#
# [261/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (335).wav
#
# [262/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (336).wav
#
# [263/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (337).wav
#
# [264/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (338).wav
#
# [265/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (339).wav
#
# [266/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (34).wav
#
# [267/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (340).wav
#
# [268/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (341).wav
#
# [269/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (342).wav
#
# [270/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (343).wav
#
# [271/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (344).wav
#
# [272/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (345).wav
#
# [273/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (346).wav
#
# [274/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (347).wav
#
# [275/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (348).wav
#
# [276/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (349).wav
#
# [277/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (35).wav
#
# [278/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (350).wav
#
# [279/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (351).wav
#
# [280/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (352).wav
#
# [281/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (353).wav
#
# [282/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (354).wav
#
# [283/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (355).wav
#
# [284/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (356).wav
#
# [285/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (357).wav
#
# [286/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (358).wav
#
# [287/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (359).wav
#
# [288/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (36).wav
#
# [289/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (360).wav
#
# [290/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (361).wav
#
# [291/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (362).wav
#
# [292/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (363).wav
#
# [293/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (364).wav
#
# [294/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (365).wav
#
# [295/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (366).wav
#
# [296/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (367).wav
#
# [297/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (368).wav
#
# [298/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (369).wav
#
# [299/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (37).wav
#
# [300/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (370).wav
#
# [301/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (371).wav
#
# [302/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (372).wav
#
# [303/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (373).wav
#
# [304/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (374).wav
#
# [305/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (375).wav
#
# [306/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (376).wav
#
# [307/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (377).wav
#
# [308/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (378).wav
#
# [309/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (379).wav
#
# [310/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (38).wav
#
# [311/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (380).wav
#
# [312/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (381).wav
#
# [313/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (382).wav
#
# [314/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (383).wav
#
# [315/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (384).wav
#
# [316/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (385).wav
#
# [317/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (386).wav
#
# [318/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (387).wav
#
# [319/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (388).wav
#
# [320/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (389).wav
#
# [321/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (39).wav
#
# [322/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (390).wav
#
# [323/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (391).wav
#
# [324/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (392).wav
#
# [325/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (393).wav
#
# [326/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (394).wav
#   [WARN] No speech found, saving whole audio
#
# [327/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (395).wav
#
# [328/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (396).wav
#
# [329/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (4).wav
#
# [330/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (40).wav
#
# [331/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (41).wav
#
# [332/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (42).wav
#
# [333/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (43).wav
#
# [334/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (44).wav
#
# [335/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (45).wav
#
# [336/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (46).wav
#
# [337/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (47).wav
#
# [338/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (48).wav
#
# [339/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (49).wav
#
# [340/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (5).wav
#
# [341/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (50).wav
#
# [342/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (51).wav
#
# [343/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (52).wav
#
# [344/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (53).wav
#
# [345/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (54).wav
#
# [346/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (55).wav
#
# [347/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (56).wav
#
# [348/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (57).wav
#
# [349/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (58).wav
#
# [350/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (59).wav
#
# [351/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (6).wav
#
# [352/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (60).wav
#
# [353/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (61).wav
#
# [354/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (62).wav
#
# [355/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (63).wav
#
# [356/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (64).wav
#
# [357/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (65).wav
#
# [358/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (66).wav
#
# [359/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (67).wav
#
# [360/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (68).wav
#
# [361/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (69).wav
#
# [362/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (7).wav
#
# [363/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (70).wav
#
# [364/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (71).wav
#
# [365/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (72).wav
#
# [366/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (73).wav
#   [WARN] No speech found, saving whole audio
#
# [367/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (74).wav
#
# [368/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (75).wav
#
# [369/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (76).wav
#
# [370/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (77).wav
#
# [371/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (78).wav
#
# [372/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (79).wav
#
# [373/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (8).wav
#
# [374/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (80).wav
#
# [375/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (81).wav
#
# [376/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (82).wav
#
# [377/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (83).wav
#
# [378/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (84).wav
#
# [379/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (85).wav
#
# [380/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (86).wav
#
# [381/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (87).wav
#
# [382/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (88).wav
#
# [383/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (89).wav
#
# [384/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (9).wav
#   [WARN] No speech found, saving whole audio
#
# [385/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (90).wav
#
# [386/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (91).wav
#
# [387/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (92).wav
#
# [388/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (93).wav
#
# [389/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (94).wav
#
# [390/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (95).wav
#
# [391/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (96).wav
#
# [392/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (97).wav
#
# [393/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (98).wav
#
# [394/5190] Processing: C:/Users/Admin/stuff/DSS/annot/aud (99).wav
#
# [395/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1).wav
#
# [396/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (10).wav
#
# [397/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (100).wav
#
# [398/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1000).wav
#
# [399/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1001).wav
#
# [400/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1002).wav
#
# [401/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1003).wav
#
# [402/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1004).wav
#
# [403/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1005).wav
#
# [404/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1006).wav
#
# [405/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1007).wav
#
# [406/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1008).wav
#
# [407/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1009).wav
#
# [408/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (101).wav
#
# [409/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1010).wav
#
# [410/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1011).wav
#
# [411/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1012).wav
#
# [412/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1013).wav
#
# [413/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1014).wav
#
# [414/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1015).wav
#
# [415/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1016).wav
#
# [416/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1017).wav
#
# [417/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1018).wav
#
# [418/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1019).wav
#
# [419/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (102).wav
#
# [420/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1020).wav
#
# [421/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1021).wav
#
# [422/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1022).wav
#
# [423/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1023).wav
#
# [424/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1024).wav
#
# [425/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1025).wav
#
# [426/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1026).wav
#
# [427/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1027).wav
#
# [428/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1028).wav
#
# [429/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1029).wav
#
# [430/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (103).wav
#
# [431/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1030).wav
#
# [432/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1031).wav
#
# [433/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1032).wav
#
# [434/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1033).wav
#
# [435/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1034).wav
#
# [436/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1035).wav
#
# [437/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1036).wav
#
# [438/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1037).wav
#
# [439/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1038).wav
#
# [440/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1039).wav
#
# [441/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (104).wav
#
# [442/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1040).wav
#
# [443/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1041).wav
#
# [444/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1042).wav
#
# [445/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1043).wav
#
# [446/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1044).wav
#
# [447/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1045).wav
#
# [448/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1046).wav
#
# [449/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1047).wav
#
# [450/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1048).wav
#
# [451/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1049).wav
#
# [452/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (105).wav
#
# [453/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1050).wav
#
# [454/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1051).wav
#
# [455/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1052).wav
#
# [456/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1053).wav
#
# [457/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1054).wav
#
# [458/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1055).wav
#
# [459/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1056).wav
#
# [460/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1057).wav
#
# [461/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1058).wav
#
# [462/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1059).wav
#
# [463/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (106).wav
#
# [464/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1060).wav
#
# [465/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1061).wav
#
# [466/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1062).wav
#
# [467/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1063).wav
#
# [468/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1064).wav
#
# [469/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1065).wav
#
# [470/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1066).wav
#
# [471/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1067).wav
#
# [472/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1068).wav
#
# [473/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1069).wav
#
# [474/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (107).wav
#
# [475/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1070).wav
#
# [476/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1071).wav
#
# [477/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1072).wav
#
# [478/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1073).wav
#
# [479/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1074).wav
#
# [480/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1075).wav
#
# [481/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1076).wav
#
# [482/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1077).wav
#
# [483/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1078).wav
#
# [484/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1079).wav
#
# [485/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (108).wav
#
# [486/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1080).wav
#
# [487/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1081).wav
#
# [488/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1082).wav
#
# [489/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1083).wav
#
# [490/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1084).wav
#
# [491/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1085).wav
#
# [492/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1086).wav
#
# [493/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1087).wav
#
# [494/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1088).wav
#
# [495/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1089).wav
#
# [496/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (109).wav
#
# [497/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1090).wav
#
# [498/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1091).wav
#
# [499/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1092).wav
#
# [500/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1093).wav
#
# [501/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1094).wav
#
# [502/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1095).wav
#
# [503/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1096).wav
#
# [504/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1097).wav
#
# [505/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1098).wav
#
# [506/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1099).wav
#
# [507/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (11).wav
#
# [508/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (110).wav
#
# [509/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1100).wav
#
# [510/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1101).wav
#
# [511/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1102).wav
#
# [512/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1103).wav
#
# [513/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1104).wav
#
# [514/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1105).wav
#
# [515/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1106).wav
#
# [516/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1107).wav
#
# [517/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1108).wav
#
# [518/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1109).wav
#
# [519/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (111).wav
#
# [520/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1110).wav
#
# [521/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1111).wav
#
# [522/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1112).wav
#
# [523/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1113).wav
#
# [524/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1114).wav
#
# [525/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1115).wav
#
# [526/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1116).wav
#
# [527/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1117).wav
#
# [528/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1118).wav
#
# [529/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1119).wav
#
# [530/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (112).wav
#
# [531/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1120).wav
#
# [532/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1121).wav
#
# [533/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1122).wav
#
# [534/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1123).wav
#
# [535/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1124).wav
#
# [536/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1125).wav
#
# [537/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1126).wav
#
# [538/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1127).wav
#
# [539/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1128).wav
#
# [540/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1129).wav
#
# [541/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (113).wav
#
# [542/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1130).wav
#
# [543/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1131).wav
#
# [544/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1132).wav
#
# [545/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1133).wav
#
# [546/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1134).wav
#
# [547/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1135).wav
#
# [548/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1136).wav
#
# [549/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1137).wav
#
# [550/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1138).wav
#
# [551/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1139).wav
#
# [552/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (114).wav
#
# [553/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1140).wav
#
# [554/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1141).wav
#
# [555/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1142).wav
#
# [556/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1143).wav
#
# [557/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1144).wav
#
# [558/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1145).wav
#
# [559/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1146).wav
#
# [560/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1147).wav
#
# [561/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1148).wav
#
# [562/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1149).wav
#
# [563/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (115).wav
#
# [564/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1150).wav
#
# [565/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1151).wav
#
# [566/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1152).wav
#
# [567/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1153).wav
#
# [568/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1154).wav
#
# [569/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1155).wav
#
# [570/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1156).wav
#
# [571/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1157).wav
#
# [572/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1158).wav
#
# [573/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1159).wav
#
# [574/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (116).wav
#
# [575/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1160).wav
#
# [576/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1161).wav
#
# [577/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1162).wav
#
# [578/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1163).wav
#
# [579/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1164).wav
#
# [580/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1165).wav
#
# [581/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1166).wav
#
# [582/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1167).wav
#
# [583/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1168).wav
#
# [584/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1169).wav
#
# [585/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (117).wav
#
# [586/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1170).wav
#
# [587/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1171).wav
#
# [588/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1172).wav
#
# [589/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1173).wav
#
# [590/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1174).wav
#
# [591/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1175).wav
#
# [592/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1176).wav
#
# [593/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1177).wav
#
# [594/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1178).wav
#
# [595/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1179).wav
#
# [596/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (118).wav
#
# [597/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1180).wav
#
# [598/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1181).wav
#
# [599/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1182).wav
#
# [600/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1183).wav
#
# [601/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1184).wav
#
# [602/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1185).wav
#
# [603/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1186).wav
#
# [604/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1187).wav
#
# [605/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1188).wav
#
# [606/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1189).wav
#
# [607/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (119).wav
#
# [608/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1190).wav
#
# [609/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1191).wav
#
# [610/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1192).wav
#
# [611/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1193).wav
#
# [612/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1194).wav
#
# [613/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1195).wav
#
# [614/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1196).wav
#
# [615/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1197).wav
#
# [616/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1198).wav
#
# [617/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1199).wav
#
# [618/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (12).wav
#
# [619/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (120).wav
#
# [620/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1200).wav
#
# [621/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1201).wav
#
# [622/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1202).wav
#   [LONG] Segment 43 is 31.4s → splitting
#
# [623/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1203).wav
#
# [624/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1204).wav
#
# [625/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1205).wav
#
# [626/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1206).wav
#
# [627/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1207).wav
#
# [628/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1208).wav
#
# [629/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1209).wav
#
# [630/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (121).wav
#
# [631/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1210).wav
#
# [632/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1211).wav
#
# [633/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1212).wav
#
# [634/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1213).wav
#
# [635/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1214).wav
#
# [636/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1215).wav
#
# [637/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1216).wav
#
# [638/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1217).wav
#
# [639/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1218).wav
#
# [640/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1219).wav
#
# [641/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (122).wav
#
# [642/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1220).wav
#
# [643/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1221).wav
#
# [644/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1222).wav
#
# [645/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1223).wav
#
# [646/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1224).wav
#
# [647/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1225).wav
#
# [648/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1226).wav
#
# [649/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1227).wav
#
# [650/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1228).wav
#
# [651/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1229).wav
#
# [652/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (123).wav
#
# [653/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1230).wav
#
# [654/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1231).wav
#
# [655/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1232).wav
#
# [656/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1233).wav
#
# [657/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1234).wav
#
# [658/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1235).wav
#
# [659/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1236).wav
#
# [660/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1237).wav
#
# [661/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1238).wav
#
# [662/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1239).wav
#
# [663/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (124).wav
#
# [664/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1240).wav
#
# [665/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1241).wav
#
# [666/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1242).wav
#
# [667/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1243).wav
#
# [668/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1244).wav
#
# [669/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1245).wav
#
# [670/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1246).wav
#
# [671/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1247).wav
#
# [672/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1248).wav
#
# [673/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1249).wav
#
# [674/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (125).wav
#
# [675/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1250).wav
#
# [676/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1251).wav
#
# [677/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1252).wav
#
# [678/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1253).wav
#
# [679/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1254).wav
#
# [680/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1255).wav
#
# [681/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1256).wav
#
# [682/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1257).wav
#
# [683/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1258).wav
#
# [684/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1259).wav
#
# [685/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (126).wav
#
# [686/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1260).wav
#
# [687/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1261).wav
#
# [688/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1262).wav
#
# [689/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1263).wav
#
# [690/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1264).wav
#
# [691/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1266).wav
#
# [692/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1267).wav
#
# [693/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1268).wav
#
# [694/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1269).wav
#
# [695/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (127).wav
#
# [696/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1270).wav
#
# [697/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1271).wav
#
# [698/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (1272).wav
#
# ...
#
# [4957/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (788).wav
#
# [4958/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (789).wav
#
# [4959/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (79).wav
#
# [4960/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (790).wav
#
# [4961/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (791).wav
#
# [4962/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (792).wav
#
# [4963/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (793).wav
#
# [4964/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (794).wav
#
# [4965/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (795).wav
#
# [4966/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (796).wav
#
# [4967/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (797).wav
#
# [4968/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (798).wav
#
# [4969/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (799).wav
#
# [4970/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (8).wav
#
# [4971/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (80).wav
#
# [4972/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (800).wav
#
# [4973/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (801).wav
#
# [4974/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (802).wav
#
# [4975/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (803).wav
#
# [4976/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (804).wav
#
# [4977/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (805).wav
#
# [4978/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (806).wav
#
# [4979/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (807).wav
#
# [4980/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (808).wav
#
# [4981/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (809).wav
#
# [4982/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (81).wav
#
# [4983/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (810).wav
#
# [4984/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (811).wav
#
# [4985/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (812).wav
#
# [4986/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (813).wav
#
# [4987/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (814).wav
#
# [4988/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (815).wav
#
# [4989/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (816).wav
#
# [4990/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (817).wav
#
# [4991/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (818).wav
#
# [4992/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (819).wav
#
# [4993/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (82).wav
#
# [4994/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (820).wav
#
# [4995/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (821).wav
#
# [4996/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (822).wav
#
# [4997/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (823).wav
#
# [4998/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (824).wav
#
# [4999/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (825).wav
#
# [5000/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (826).wav
#
# [5001/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (827).wav
#
# [5002/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (828).wav
#
# [5003/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (829).wav
#
# [5004/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (83).wav
#
# [5005/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (830).wav
#
# [5006/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (831).wav
#
# [5007/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (832).wav
#
# [5008/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (833).wav
#
# [5009/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (834).wav
#
# [5010/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (835).wav
#
# [5011/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (836).wav
#
# [5012/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (837).wav
#
# [5013/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (838).wav
#
# [5014/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (839).wav
#
# [5015/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (84).wav
#
# [5016/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (840).wav
#
# [5017/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (841).wav
#
# [5018/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (842).wav
#
# [5019/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (843).wav
#
# [5020/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (844).wav
#
# [5021/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (845).wav
#
# [5022/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (846).wav
#
# [5023/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (847).wav
#
# [5024/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (848).wav
#
# [5025/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (849).wav
#
# [5026/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (85).wav
#
# [5027/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (850).wav
#
# [5028/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (851).wav
#
# [5029/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (852).wav
#
# [5030/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (853).wav
#
# [5031/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (854).wav
#
# [5032/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (855).wav
#
# [5033/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (856).wav
#
# [5034/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (857).wav
#
# [5035/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (858).wav
#
# [5036/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (859).wav
#
# [5037/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (86).wav
#
# [5038/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (860).wav
#
# [5039/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (861).wav
#
# [5040/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (862).wav
#
# [5041/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (863).wav
#
# [5042/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (864).wav
#
# [5043/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (865).wav
#
# [5044/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (866).wav
#   [LONG] Segment 82 is 31.6s → splitting
#
# [5045/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (867).wav
#
# [5046/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (868).wav
#
# [5047/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (869).wav
#
# [5048/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (87).wav
#
# [5049/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (870).wav
#
# [5050/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (871).wav
#
# [5051/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (872).wav
#
# [5052/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (873).wav
#
# [5053/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (874).wav
#
# [5054/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (875).wav
#
# [5055/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (876).wav
#
# [5056/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (877).wav
#
# [5057/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (878).wav
#
# [5058/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (879).wav
#
# [5059/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (88).wav
#
# [5060/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (880).wav
#
# [5061/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (881).wav
#
# [5062/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (882).wav
#
# [5063/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (883).wav
#
# [5064/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (884).wav
#
# [5065/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (885).wav
#
# [5066/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (886).wav
#
# [5067/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (887).wav
#
# [5068/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (888).wav
#
# [5069/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (889).wav
#
# [5070/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (89).wav
#
# [5071/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (890).wav
#
# [5072/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (891).wav
#
# [5073/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (892).wav
#
# [5074/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (893).wav
#
# [5075/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (894).wav
#
# [5076/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (895).wav
#
# [5077/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (896).wav
#
# [5078/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (897).wav
#
# [5079/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (898).wav
#
# [5080/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (899).wav
#
# [5081/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (9).wav
#
# [5082/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (90).wav
#
# [5083/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (900).wav
#
# [5084/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (901).wav
#
# [5085/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (902).wav
#
# [5086/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (903).wav
#
# [5087/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (904).wav
#
# [5088/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (905).wav
#
# [5089/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (906).wav
#
# [5090/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (907).wav
#
# [5091/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (908).wav
#
# [5092/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (909).wav
#
# [5093/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (91).wav
#
# [5094/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (910).wav
#
# [5095/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (911).wav
#
# [5096/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (912).wav
#
# [5097/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (913).wav
#
# [5098/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (914).wav
#
# [5099/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (915).wav
#
# [5100/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (916).wav
#
# [5101/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (917).wav
#
# [5102/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (918).wav
#
# [5103/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (919).wav
#
# [5104/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (92).wav
#
# [5105/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (920).wav
#
# [5106/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (921).wav
#
# [5107/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (922).wav
#
# [5108/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (923).wav
#
# [5109/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (924).wav
#
# [5110/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (925).wav
#
# [5111/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (926).wav
#
# [5112/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (927).wav
#
# [5113/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (928).wav
#
# [5114/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (929).wav
#
# [5115/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (93).wav
#
# [5116/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (930).wav
#
# [5117/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (931).wav
#
# [5118/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (932).wav
#
# [5119/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (933).wav
#
# [5120/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (934).wav
#
# [5121/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (935).wav
#
# [5122/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (936).wav
#
# [5123/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (937).wav
#
# [5124/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (939).wav
#
# [5125/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (94).wav
#
# [5126/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (940).wav
#
# [5127/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (941).wav
#
# [5128/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (942).wav
#
# [5129/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (943).wav
#
# [5130/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (944).wav
#
# [5131/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (945).wav
#
# [5132/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (946).wav
#
# [5133/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (947).wav
#
# [5134/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (948).wav
#
# [5135/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (949).wav
#
# [5136/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (95).wav
#
# [5137/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (950).wav
#
# [5138/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (951).wav
#
# [5139/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (952).wav
#
# [5140/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (953).wav
#
# [5141/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (954).wav
#
# [5142/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (955).wav
#
# [5143/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (956).wav
#
# [5144/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (957).wav
#
# [5145/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (958).wav
#
# [5146/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (959).wav
#
# [5147/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (96).wav
#
# [5148/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (960).wav
#
# [5149/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (961).wav
#
# [5150/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (962).wav
#
# [5151/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (963).wav
#
# [5152/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (964).wav
#
# [5153/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (965).wav
#
# [5154/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (966).wav
#
# [5155/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (967).wav
#
# [5156/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (968).wav
#
# [5157/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (969).wav
#
# [5158/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (97).wav
#
# [5159/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (970).wav
#
# [5160/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (971).wav
#
# [5161/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (972).wav
#
# [5162/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (973).wav
#
# [5163/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (974).wav
#
# [5164/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (975).wav
#
# [5165/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (976).wav
#
# [5166/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (977).wav
#
# [5167/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (978).wav
#
# [5168/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (979).wav
#
# [5169/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (98).wav
#
# [5170/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (980).wav
#
# [5171/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (981).wav
#
# [5172/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (982).wav
#
# [5173/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (983).wav
#
# [5174/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (984).wav
#
# [5175/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (985).wav
#
# [5176/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (986).wav
#
# [5177/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (987).wav
#
# [5178/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (988).wav
#
# [5179/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (989).wav
#
# [5180/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (99).wav
#
# [5181/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (990).wav
#
# [5182/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (991).wav
#
# [5183/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (992).wav
#
# [5184/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (993).wav
#
# [5185/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (994).wav
#
# [5186/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (995).wav
#
# [5187/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (996).wav
#
# [5188/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (997).wav
#
# [5189/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (998).wav
#
# [5190/5190] Processing: C:/Users/Admin/stuff/DSS/annot/m (999).wav
#
# ✅ Done: 452584 segments saved to manifest_silero_v2.jsonl
